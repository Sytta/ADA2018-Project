# %% [markdown]
# # Data Exploration & Insights

# %%
# preliminary imports
import numpy as np
import pandas as pd

# %%
# name data folder and files
data_folder = './data/'
data_file = 'OECD_Mental_Health_Stats.csv'

# %%
# import data to pandas dataframe
mental_health_data = pd.read_csv(data_folder + data_file)

# %%
# Dataframe we will be working with
mental_health_data.head()
# Out:
#   COUNTRY  Country ISC11A                     ISCED-A 2011 SEX Gender     AGE  \
# 0     AUT  Austria   L0T2  Below upper secondary education   T  Total  Y25T44
# 1     AUT  Austria   L0T2  Below upper secondary education   F  Women  Y25T44
# 2     AUT  Austria   L0T2  Below upper secondary education   M    Men  Y25T44
# 3     AUT  Austria   L0T2  Below upper secondary education   T  Total  Y25T44
# 4     AUT  Austria   L0T2  Below upper secondary education   F  Women  Y25T44
#
#            Age PIAAC_CATEGORY  Category             INDICATOR  \
# 0  25-44 years              E  Employed  PIAAC_PERC_DEPRESSED
# 1  25-44 years              E  Employed  PIAAC_PERC_DEPRESSED
# 2  25-44 years              E  Employed  PIAAC_PERC_DEPRESSED
# 3  25-44 years              T     Total  PIAAC_PERC_DEPRESSED
# 4  25-44 years              T     Total  PIAAC_PERC_DEPRESSED
#
#                                            Indicator MEASURE Measure  YEAR  \
# 0  Percentage of adults who report having depression   VALUE   Value  2014
# 1  Percentage of adults who report having depression   VALUE   Value  2014
# 2  Percentage of adults who report having depression   VALUE   Value  2014
# 3  Percentage of adults who report having depression   VALUE   Value  2014
# 4  Percentage of adults who report having depression   VALUE   Value  2014
#
#    Reference year    Value Flag Codes Flags
# 0            2014   6.5209        NaN   NaN
# 1            2014   8.8432        NaN   NaN
# 2            2014   2.7627        NaN   NaN
# 3            2014  12.8613        NaN   NaN
# 4            2014  12.2516        NaN   NaN
